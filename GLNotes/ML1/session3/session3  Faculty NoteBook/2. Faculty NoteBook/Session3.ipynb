# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('employee_compensation.csv')
df.head().transpose()
# Out:
#                              0         1          2         3         4
# Year_Type               Fiscal  Calendar     Fiscal    Fiscal    Fiscal
# Year                      2015      2015       2014      2014      2013
# Employee_Identifier      42853     28248      30651     19473      7176
# Salaries              92288.22   1466.38   76536.95  45659.88   41832.0
# Overtime                267.45    348.23   13583.72       0.0       0.0
# Other_Salaries          267.45       0.0   10855.94   1625.37       0.0
# Total_Salary          92823.12   1814.61  100976.61  47285.25   41832.0
# Retirement             20700.2       0.0   18632.19   10081.2    7617.6
# Health/Dental         12500.56    442.03   12464.61       0.0   5908.52
# Other_Benefits         7605.75    141.59    8011.41   3936.63    3254.5
# Total_Benefits        40806.51    583.62   39108.21  14017.83  16780.62
# Total_Compensation   133629.63   2398.23  140084.82  61303.08  58612.62

# %%
df.dtypes
# Out:
# Year_Type               object
# Year                     int64
# Employee_Identifier      int64
# Salaries               float64
# Overtime               float64
# Other_Salaries         float64
# Total_Salary           float64
# Retirement             float64
# Health/Dental          float64
# Other_Benefits         float64
# Total_Benefits         float64
# Total_Compensation     float64
# dtype: object

# %%
df['Year'] = df['Year'].astype(object)

# %%
df.dtypes
# Out:
# Year_Type               object
# Year                    object
# Employee_Identifier      int64
# Salaries               float64
# Overtime               float64
# Other_Salaries         float64
# Total_Salary           float64
# Retirement             float64
# Health/Dental          float64
# Other_Benefits         float64
# Total_Benefits         float64
# Total_Compensation     float64
# dtype: object

# %%
df = df.drop('Employee_Identifier',axis=1)
df.dtypes
# Out:
# Year_Type              object
# Year                   object
# Salaries              float64
# Overtime              float64
# Other_Salaries        float64
# Total_Salary          float64
# Retirement            float64
# Health/Dental         float64
# Other_Benefits        float64
# Total_Benefits        float64
# Total_Compensation    float64
# dtype: object

# %%
plt.figure(figsize=(15,8))

df.boxplot()
plt.title("Plot of all numerical variables")
plt.xticks(rotation='vertical',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15,8))
df.loc[:,['Overtime', 'Other_Salaries', 'Retirement', 'Other_Benefits', 'Total_Benefits']].boxplot()
plt.title("Plot of independent variables")
plt.xticks(rotation='vertical',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(df['Total_Compensation'])
plt.title("Total Compensation (Dependent Variable)");
plt.xlabel("Total_Compensation")

plt.show()

# %%
q1 = df.quantile(0.25)
q3 = df.quantile(0.75)
iqr = q3 - q1
outlier1 = q1 - 1.5*iqr
outlier2 = q3 + 1.5*iqr

df_wo_outlier = df[~(df < outlier1 | df > outlier2).any(axis=1)]
df_wo_outlier.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 q1 = df.quantile(0.25)
#       2 q3 = df.quantile(0.75)
#       3 iqr = q3 - q1
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:10882, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   10875 axis = self._get_axis_number(axis)
#   10877 if not is_list_like(q):
#   10878     # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   10879     # error: List item 0 has incompatible type "Union[float, Union[Union[
#   10880     # ExtensionArray, ndarray[Any, Any]], Index, Series], Sequence[float]]";
#   10881     # expected "float"
# > 10882     res_df = self.quantile(  # type: ignore[call-overload]
#   10883         [q],
#   10884         axis=axis,
#   10885         numeric_only=numeric_only,
#   10886         interpolation=interpolation,
# ...

# %%
# load the csv file
# store the data in 'df_compensation'
df_compensation = pd.read_csv('employee_compensation.csv')

# display first five observations using head()
df_compensation.head()
# Out:
#   Year_Type  Year  Employee_Identifier  Salaries  Overtime  Other_Salaries  \
# 0    Fiscal  2015                42853  92288.22    267.45          267.45
# 1  Calendar  2015                28248   1466.38    348.23            0.00
# 2    Fiscal  2014                30651  76536.95  13583.72        10855.94
# 3    Fiscal  2014                19473  45659.88      0.00         1625.37
# 4    Fiscal  2013                 7176  41832.00      0.00            0.00
#
#    Total_Salary  Retirement  Health/Dental  Other_Benefits  Total_Benefits  \
# 0      92823.12    20700.20       12500.56         7605.75        40806.51
# 1       1814.61        0.00         442.03          141.59          583.62
# 2     100976.61    18632.19       12464.61         8011.41        39108.21
# 3      47285.25    10081.20           0.00         3936.63        14017.83
# 4      41832.00     7617.60        5908.52         3254.50        16780.62
#
#    Total_Compensation
# 0           133629.63
# ...

# %%
Q1 = df_compensation.quantile(0.25)

# calculate the third quartile
Q3 = df_compensation.quantile(0.75)

# The Interquartile Range (IQR) is defined as the difference between the third and first quartile
# calculate IQR for each numeric variable
IQR = Q3 - Q1

# retrieve the dataframe without the outliers
# '~' returns the values that do not satisfy the given conditions 
# i.e. it returns values between the range [Q1-1.5*IQR, Q3+1.5*IQR]
# '|' is used as 'OR' operator on multiple conditions   
# 'any(axis=1)' checks the entire row for atleast one 'True' entry (those rows represents outliers in the data)
df_compensation = df_compensation[~((df_compensation < (Q1 - 1.5 * IQR)) | (df_compensation > (Q3 + 1.5 * IQR))).any(axis=1)]

# check the shape of the data
df_compensation.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 Q1 = df_compensation.quantile(0.25)
#       3 # calculate the third quartile
#       4 Q3 = df_compensation.quantile(0.75)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:10882, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   10875 axis = self._get_axis_number(axis)
#   10877 if not is_list_like(q):
#   10878     # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   10879     # error: List item 0 has incompatible type "Union[float, Union[Union[
#   10880     # ExtensionArray, ndarray[Any, Any]], Index, Series], Sequence[float]]";
#   10881     # expected "float"
# > 10882     res_df = self.quantile(  # type: ignore[call-overload]
#   10883         [q],
#   10884         axis=axis,
#   10885         numeric_only=numeric_only,
# ...

# %%
df.quantile(0.35)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.quantile(0.35)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:10882, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   10875 axis = self._get_axis_number(axis)
#   10877 if not is_list_like(q):
#   10878     # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   10879     # error: List item 0 has incompatible type "Union[float, Union[Union[
#   10880     # ExtensionArray, ndarray[Any, Any]], Index, Series], Sequence[float]]";
#   10881     # expected "float"
# > 10882     res_df = self.quantile(  # type: ignore[call-overload]
#   10883         [q],
#   10884         axis=axis,
#   10885         numeric_only=numeric_only,
#   10886         interpolation=interpolation,
#   10887         method=method,
#   10888     )
# ...
