# %%
import pandas as pd
import numpy as np

# %%
bollywood_df = pd.read_csv('../Machine-Learning-with-Python-/bollywood.csv')
bollywood_df.head().transpose()
# Out:
#                              0             1                   2  \
# SlNo                         1             2                   3
# Release Date         18-Apr-14      4-Jan-13           18-Jul-14
# MovieName             2 States  Table No. 21  Amit Sahni Ki List
# ReleaseTime                 LW             N                   N
# Genre                  Romance     Thriller               Comedy
# Budget                      36            10                  10
# BoxOfficeCollection      104.0          12.0                 4.0
# YoutubeViews           8576361       1087320              572336
# YoutubeLikes             26622          1129                 586
# YoutubeDislikes           2527           137                  54
#
#                                     3             4
# SlNo                                4             5
# Release Date                 4-Jan-13      4-Jul-14
# MovieName            Rajdhani Express  Bobby Jasoos
# ...

# %%
list(bollywood_df.columns)
# Out:
# ['SlNo',
#  'Release Date',
#  'MovieName',
#  'ReleaseTime',
#  'Genre',
#  'Budget',
#  'BoxOfficeCollection',
#  'YoutubeViews',
#  'YoutubeLikes',
#  'YoutubeDislikes']

# %%
bollywood_df.describe()
# Out:
#              SlNo      Budget  BoxOfficeCollection  YoutubeViews  \
# count  149.000000  149.000000           149.000000  1.490000e+02
# mean    75.000000   29.442953            55.667248  3.337920e+06
# std     43.156691   28.237981            94.494531  3.504407e+06
# min      1.000000    2.000000             0.010000  4.354000e+03
# 25%     38.000000   11.000000             8.780000  1.076591e+06
# 50%     75.000000   21.000000            28.000000  2.375050e+06
# 75%    112.000000   35.000000            57.450000  4.550051e+06
# max    149.000000  150.000000           735.000000  2.317107e+07
#
#         YoutubeLikes  YoutubeDislikes
# count     149.000000       149.000000
# mean     7877.536913      1207.818792
# std     12748.047191      1852.692938
# min         1.000000         1.000000
# 25%      1377.000000       189.000000
# 50%      4111.000000       614.000000
# 75%      9100.000000      1419.000000
# max    101275.000000     11888.000000

# %%
bollywood_df.shape
# Out:
# (149, 10)

# %%
bollywood_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    object
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 11.8+ KB

# %%
# Movies released in each genre
bollywood_df.Genre.value_counts()
# Out:
# Genre
# Comedy       36
#  Drama       35
# Thriller     26
# Romance      25
# Action       21
# Thriller      3
# Action        3
# Name: count, dtype: int64

# %%
#Which Genre has highest number of releases?
print("Comedy Genre has the highest number of releases")
bollywood_df.Genre.value_counts(ascending=True)
# Out:
# Comedy Genre has the highest number of releases
# Genre
# Thriller      3
# Action        3
# Action       21
# Romance      25
# Thriller     26
#  Drama       35
# Comedy       36
# Name: count, dtype: int64

# %% [markdown]
# # How many movies in each genre got released in different release times like long weekend, festive season, etc. (Note: Do a cross tabulation between Genre and ReleaseTime.)

# %%
releaseTime_df = pd.crosstab(bollywood_df.Genre,bollywood_df.ReleaseTime)
releaseTime_df.rename({
    'FS':"Festival Season",
    'HS':"Holiday Season",
    'LW':"Long Weekend",
    'N':"Normal"
},axis=1,inplace=True)

releaseTime_df
# Out:
# ReleaseTime  Festival Season  Holiday Season  Long Weekend  Normal
# Genre
#  Drama                     4               6             1      24
# Action                     3               3             3      12
# Action                     0               0             0       3
# Comedy                     3               5             5      23
# Romance                    3               3             4      15
# Thriller                   4               1             1      20
# Thriller                   0               0             1       2

# %% [markdown]
# # Which month of the year, maximum number movie releases are seen? (Note: Extract a new column called month from ReleaseDate column.)

# %%
def ReleaseMonth(date_):
    
    return date_.split("-")[1];

ReleaseMonth("18-Jul-14")
# Out:
# 'Jul'

# %%
bollywood_df['ReleaseMonth'] = bollywood_df.apply(lambda x:x['Release Date'].split("-")[1],axis=1)
bollywood_df.ReleaseMonth.value_counts()
# Out:
# ReleaseMonth
# Jan    20
# Mar    19
# May    18
# Jul    16
# Feb    16
# Apr    11
# Sep    10
# Jun    10
# Nov    10
# Oct     9
# Aug     8
# Dec     2
# Name: count, dtype: int64

# %%
print("Jan month has the maximum number of movie release")
# Out:
# Jan month has the maximum number of movie release

# %% [markdown]
# # Which month of the year typically sees most releases of high budgeted movies, that is, movies with budget of 25 crore or more?

# %%
bollywood_df[bollywood_df.Budget >= 25].ReleaseMonth.value_counts()
# Out:
# ReleaseMonth
# Feb    9
# Jan    8
# Mar    7
# Aug    7
# Nov    6
# Jul    6
# Sep    5
# Jun    5
# Apr    4
# Oct    4
# May    3
# Dec    2
# Name: count, dtype: int64

# %%
print("Feb month of the year typically sees most releases of high budgeted movies")
# Out:
# Feb month of the year typically sees most releases of high budgeted movies

# %% [markdown]
# # Which are the top 10 movies with maximum return on investment (ROI)? Calculate return on investment (ROI) as (BoxOfficeCollection – Budget) / Budget.

# %%
bollywood_df['roi'] = bollywood_df.apply(lambda x:(x.BoxOfficeCollection-x.Budget)/x.Budget,axis=1)
bollywood_df.sort_values(by='roi',ascending=False).head(10)[['MovieName','roi']]
# Out:
#                      MovieName       roi
# 64                  Aashiqui 2  8.166667
# 89                          PK  7.647059
# 132                Grand Masti  7.514286
# 135               The Lunchbox  7.500000
# 87                      Fukrey  6.240000
# 58                    Mary Kom  5.933333
# 128                     Shahid  5.666667
# 37   Humpty Sharma Ki Dulhania  5.500000
# 101         Bhaag Milkha Bhaag  4.466667
# 115            Chennai Express  4.266667

# %% [markdown]
# # Do the movies have higher ROI if they get released on festive seasons or long weekend? Calculate the average ROI for different release times.

# %%
bollywood_df.sort_values(by='roi',ascending=False).head(10)[['MovieName','roi','ReleaseTime']]
# Out:
#                      MovieName       roi ReleaseTime
# 64                  Aashiqui 2  8.166667           N
# 89                          PK  7.647059          HS
# 132                Grand Masti  7.514286          LW
# 135               The Lunchbox  7.500000           N
# 87                      Fukrey  6.240000           N
# 58                    Mary Kom  5.933333           N
# 128                     Shahid  5.666667          FS
# 37   Humpty Sharma Ki Dulhania  5.500000           N
# 101         Bhaag Milkha Bhaag  4.466667           N
# 115            Chennai Express  4.266667          FS

# %%
bollywood_df.groupby('ReleaseTime')['roi'].mean().reset_index()
# Out:
#   ReleaseTime       roi
# 0          FS  0.973853
# 1          HS  0.850867
# 2          LW  1.127205
# 3           N  0.657722

# %%
print("Movies have higher returns if they are released on Long Weekends")
# Out:
# Movies have higher returns if they are released on Long Weekends

# %% [markdown]
# # Draw a histogram and a distribution plot to find out the distribution of movie budgets. Interpret the plot to conclude if the most movies are high or low budgeted movies.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(x=bollywood_df.Budget,bins=20)
plt.title("Movies")
plt.xlabel("Budget in Crores")
plt.ylabel("Count")
plt.show()

# %%
sns.distplot(x=bollywood_df.Budget,bins=20)
plt.show()
# Out:
# /tmp/ipykernel_4568/983977746.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=bollywood_df.Budget,bins=20)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(bollywood_df.Budget, bins=20, kde=False, color='skyblue')
plt.title('Distribution of Movie Budgets')
plt.xlabel('Budget')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(bollywood_df.Budget, color='skyblue', fill=True)
plt.title('Kernel Density Estimation (KDE) of Movie Budgets')
plt.xlabel('Budget')
plt.ylabel('Density')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %%
plt.figure(figsize=(10, 6))
plt.hist(bollywood_df.Budget, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Movie Budgets')
plt.xlabel('Budget')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %% [markdown]
# # Compare the distribution of ROIs between movies with comedy genre and drama. Which genre typically sees higher ROIs?

# %%
bollywood_df.Genre.unique()
# Out:
# array(['Romance', 'Thriller ', 'Comedy', ' Drama ', 'Action ', 'Action',
#        'Thriller'], dtype=object)

# %%
sns.distplot(bollywood_df[bollywood_df.Genre=="Comedy"]['roi'],color='g',label='Comedy')
sns.distplot(bollywood_df[bollywood_df.Genre==" Drama "]['roi'],color='b',label='Drama')
plt.title("ROI")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_4568/1064182091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(bollywood_df[bollywood_df.Genre=="Comedy"]['roi'],color='g',label='Comedy')
# /tmp/ipykernel_4568/1064182091.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
print("Comedy Genre sees higher ROI")
# Out:
# Comedy Genre sees higher ROI

# %% [markdown]
# # Is there a correlation between box office collection and YouTube likes? Is the correlation positive or negative?

# %%
correlation = bollywood_df['BoxOfficeCollection'].corr(bollywood_df['YoutubeLikes'])

# Determine if correlation is positive, negative, or close to zero
if correlation > 0:
    correlation_direction = "positive"
elif correlation < 0:
    correlation_direction = "negative"
else:
    correlation_direction = "little to no"

# Print correlation coefficient and direction
print(f"Correlation coefficient: {correlation}")
print(f"Correlation direction: {correlation_direction}")
# Out:
# Correlation coefficient: 0.6825165877731297
# Correlation direction: positive

# %% [markdown]
# # Which genre of movies typically sees more YouTube likes? Draw boxplots for each genre of movies to compare.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Genre',y='YoutubeLikes',data=bollywood_df)
plt.show()

# %%
print("Action movies typically sees more YouTube Likes")
# Out:
# Action movies typically sees more YouTube Likes

# %% [markdown]
# # Which of the variables among Budget, BoxOfficeCollection, YoutubeView, YoutubeLikes, YoutubeDislikes are highly correlated? Note: Draw pair plot or heatmap.

# %%
influential_features = ['Budget','BoxOfficeCollection','YoutubeViews','YoutubeLikes','YoutubeDislikes']
sns.pairplot(bollywood_df[influential_features],size=2)
plt.show()
# Out:
# /home/nksys/.local/lib/python3.9/site-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /home/nksys/.local/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
